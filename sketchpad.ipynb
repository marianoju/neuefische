# %%
import itertools

# %%
def calc_len(x):
    return len(x)

# %%
""" --------------------------------------------------------------------
define independent variables and target variable
-------------------------------------------------------------------- """

features     = ["longitude", "latitude", "housing_median_age", \
                "total_rooms", "total_bedrooms", "population", \
                "households", "median_income"]
target       = ["median_house_value"]

combinations = []

for i in range(2, len(features)+1):
    combinations += itertools.combinations(features, i)

# %%
len(combinations)
# Out:
# 247

# %%
type(combinations)
# Out:
# list

# %%
combinations
# Out:
# [('longitude', 'latitude'),
#  ('longitude', 'housing_median_age'),
#  ('longitude', 'total_rooms'),
#  ('longitude', 'total_bedrooms'),
#  ('longitude', 'population'),
#  ('longitude', 'households'),
#  ('longitude', 'median_income'),
#  ('latitude', 'housing_median_age'),
#  ('latitude', 'total_rooms'),
#  ('latitude', 'total_bedrooms'),
#  ('latitude', 'population'),
#  ('latitude', 'households'),
#  ('latitude', 'median_income'),
#  ('housing_median_age', 'total_rooms'),
#  ('housing_median_age', 'total_bedrooms'),
#  ('housing_median_age', 'population'),
#  ('housing_median_age', 'households'),
#  ('housing_median_age', 'median_income'),
#  ('total_rooms', 'total_bedrooms'),
#  ('total_rooms', 'population'),
#  ('total_rooms', 'households'),
#  ('total_rooms', 'median_income'),
#  ('total_bedrooms', 'population'),
#  ('total_bedrooms', 'households'),
#  ('total_bedrooms', 'median_income'),
#  ('population', 'households'),
#  ('population', 'median_income'),
#  ('households', 'median_income'),
#  ('longitude', 'latitude', 'housing_median_age'),
#  ('longitude', 'latitude', 'total_rooms'),
#  ('longitude', 'latitude', 'total_bedrooms'),
#  ('longitude', 'latitude', 'population'),
#  ('longitude', 'latitude', 'households'),
#  ('longitude', 'latitude', 'median_income'),
#  ('longitude', 'housing_median_age', 'total_rooms'),
#  ('longitude', 'housing_median_age', 'total_bedrooms'),
#  ('longitude', 'housing_median_age', 'population'),
#  ('longitude', 'housing_median_age', 'households'),
#  ('longitude', 'housing_median_age', 'median_income'),
#  ('longitude', 'total_rooms', 'total_bedrooms'),
#  ('longitude', 'total_rooms', 'population'),
#  ('longitude', 'total_rooms', 'households'),
#  ('longitude', 'total_rooms', 'median_income'),
#  ('longitude', 'total_bedrooms', 'population'),
#  ('longitude', 'total_bedrooms', 'households'),
#  ('longitude', 'total_bedrooms', 'median_income'),
#  ('longitude', 'population', 'households'),
#  ('longitude', 'population', 'median_income'),
#  ('longitude', 'households', 'median_income'),
#  ('latitude', 'housing_median_age', 'total_rooms'),
#  ('latitude', 'housing_median_age', 'total_bedrooms'),
#  ('latitude', 'housing_median_age', 'population'),
#  ('latitude', 'housing_median_age', 'households'),
#  ('latitude', 'housing_median_age', 'median_income'),
#  ('latitude', 'total_rooms', 'total_bedrooms'),
#  ('latitude', 'total_rooms', 'population'),
#  ('latitude', 'total_rooms', 'households'),
#  ('latitude', 'total_rooms', 'median_income'),
#  ('latitude', 'total_bedrooms', 'population'),
#  ('latitude', 'total_bedrooms', 'households'),
#  ('latitude', 'total_bedrooms', 'median_income'),
#  ('latitude', 'population', 'households'),
#  ('latitude', 'population', 'median_income'),
#  ('latitude', 'households', 'median_income'),
#  ('housing_median_age', 'total_rooms', 'total_bedrooms'),
#  ('housing_median_age', 'total_rooms', 'population'),
#  ('housing_median_age', 'total_rooms', 'households'),
#  ('housing_median_age', 'total_rooms', 'median_income'),
#  ('housing_median_age', 'total_bedrooms', 'population'),
#  ('housing_median_age', 'total_bedrooms', 'households'),
#  ('housing_median_age', 'total_bedrooms', 'median_income'),
#  ('housing_median_age', 'population', 'households'),
#  ('housing_median_age', 'population', 'median_income'),
#  ('housing_median_age', 'households', 'median_income'),
#  ('total_rooms', 'total_bedrooms', 'population'),
#  ('total_rooms', 'total_bedrooms', 'households'),
#  ('total_rooms', 'total_bedrooms', 'median_income'),
#  ('total_rooms', 'population', 'households'),
#  ('total_rooms', 'population', 'median_income'),
#  ('total_rooms', 'households', 'median_income'),
#  ('total_bedrooms', 'population', 'households'),
#  ('total_bedrooms', 'population', 'median_income'),
#  ('total_bedrooms', 'households', 'median_income'),
#  ('population', 'households', 'median_income'),
#  ('longitude', 'latitude', 'housing_median_age', 'total_rooms'),
#  ('longitude', 'latitude', 'housing_median_age', 'total_bedrooms'),
#  ('longitude', 'latitude', 'housing_median_age', 'population'),
#  ('longitude', 'latitude', 'housing_median_age', 'households'),
#  ('longitude', 'latitude', 'housing_median_age', 'median_income'),
#  ('longitude', 'latitude', 'total_rooms', 'total_bedrooms'),
#  ('longitude', 'latitude', 'total_rooms', 'population'),
#  ('longitude', 'latitude', 'total_rooms', 'households'),
#  ('longitude', 'latitude', 'total_rooms', 'median_income'),
#  ('longitude', 'latitude', 'total_bedrooms', 'population'),
#  ('longitude', 'latitude', 'total_bedrooms', 'households'),
#  ('longitude', 'latitude', 'total_bedrooms', 'median_income'),
#  ('longitude', 'latitude', 'population', 'households'),
#  ('longitude', 'latitude', 'population', 'median_income'),
#  ('longitude', 'latitude', 'households', 'median_income'),
#  ('longitude', 'housing_median_age', 'total_rooms', 'total_bedrooms'),
#  ('longitude', 'housing_median_age', 'total_rooms', 'population'),
#  ('longitude', 'housing_median_age', 'total_rooms', 'households'),
#  ('longitude', 'housing_median_age', 'total_rooms', 'median_income'),
#  ('longitude', 'housing_median_age', 'total_bedrooms', 'population'),
#  ('longitude', 'housing_median_age', 'total_bedrooms', 'households'),
#  ('longitude', 'housing_median_age', 'total_bedrooms', 'median_income'),
#  ('longitude', 'housing_median_age', 'population', 'households'),
#  ('longitude', 'housing_median_age', 'population', 'median_income'),
#  ('longitude', 'housing_median_age', 'households', 'median_income'),
#  ('longitude', 'total_rooms', 'total_bedrooms', 'population'),
#  ('longitude', 'total_rooms', 'total_bedrooms', 'households'),
#  ('longitude', 'total_rooms', 'total_bedrooms', 'median_income'),
#  ('longitude', 'total_rooms', 'population', 'households'),
#  ('longitude', 'total_rooms', 'population', 'median_income'),
#  ('longitude', 'total_rooms', 'households', 'median_income'),
#  ('longitude', 'total_bedrooms', 'population', 'households'),
#  ('longitude', 'total_bedrooms', 'population', 'median_income'),
#  ('longitude', 'total_bedrooms', 'households', 'median_income'),
#  ('longitude', 'population', 'households', 'median_income'),
#  ('latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms'),
#  ('latitude', 'housing_median_age', 'total_rooms', 'population'),
#  ('latitude', 'housing_median_age', 'total_rooms', 'households'),
#  ('latitude', 'housing_median_age', 'total_rooms', 'median_income'),
#  ('latitude', 'housing_median_age', 'total_bedrooms', 'population'),
#  ('latitude', 'housing_median_age', 'total_bedrooms', 'households'),
#  ('latitude', 'housing_median_age', 'total_bedrooms', 'median_income'),
#  ('latitude', 'housing_median_age', 'population', 'households'),
#  ('latitude', 'housing_median_age', 'population', 'median_income'),
#  ('latitude', 'housing_median_age', 'households', 'median_income'),
#  ('latitude', 'total_rooms', 'total_bedrooms', 'population'),
#  ('latitude', 'total_rooms', 'total_bedrooms', 'households'),
#  ('latitude', 'total_rooms', 'total_bedrooms', 'median_income'),
#  ('latitude', 'total_rooms', 'population', 'households'),
#  ('latitude', 'total_rooms', 'population', 'median_income'),
#  ('latitude', 'total_rooms', 'households', 'median_income'),
#  ('latitude', 'total_bedrooms', 'population', 'households'),
#  ('latitude', 'total_bedrooms', 'population', 'median_income'),
#  ('latitude', 'total_bedrooms', 'households', 'median_income'),
#  ('latitude', 'population', 'households', 'median_income'),
#  ('housing_median_age', 'total_rooms', 'total_bedrooms', 'population'),
#  ('housing_median_age', 'total_rooms', 'total_bedrooms', 'households'),
#  ('housing_median_age', 'total_rooms', 'total_bedrooms', 'median_income'),
#  ('housing_median_age', 'total_rooms', 'population', 'households'),
#  ('housing_median_age', 'total_rooms', 'population', 'median_income'),
#  ('housing_median_age', 'total_rooms', 'households', 'median_income'),
#  ('housing_median_age', 'total_bedrooms', 'population', 'households'),
#  ('housing_median_age', 'total_bedrooms', 'population', 'median_income'),
#  ('housing_median_age', 'total_bedrooms', 'households', 'median_income'),
#  ('housing_median_age', 'population', 'households', 'median_income'),
#  ('total_rooms', 'total_bedrooms', 'population', 'households'),
#  ('total_rooms', 'total_bedrooms', 'population', 'median_income'),
#  ('total_rooms', 'total_bedrooms', 'households', 'median_income'),
#  ('total_rooms', 'population', 'households', 'median_income'),
#  ('total_bedrooms', 'population', 'households', 'median_income'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms'),
#  ('longitude', 'latitude', 'housing_median_age', 'total_rooms', 'population'),
#  ('longitude', 'latitude', 'housing_median_age', 'total_rooms', 'households'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'population'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'households'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'median_income'),
#  ('longitude', 'latitude', 'housing_median_age', 'population', 'households'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'population',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'households',
#   'median_income'),
#  ('longitude', 'latitude', 'total_rooms', 'total_bedrooms', 'population'),
#  ('longitude', 'latitude', 'total_rooms', 'total_bedrooms', 'households'),
#  ('longitude', 'latitude', 'total_rooms', 'total_bedrooms', 'median_income'),
#  ('longitude', 'latitude', 'total_rooms', 'population', 'households'),
#  ('longitude', 'latitude', 'total_rooms', 'population', 'median_income'),
#  ('longitude', 'latitude', 'total_rooms', 'households', 'median_income'),
#  ('longitude', 'latitude', 'total_bedrooms', 'population', 'households'),
#  ('longitude', 'latitude', 'total_bedrooms', 'population', 'median_income'),
#  ('longitude', 'latitude', 'total_bedrooms', 'households', 'median_income'),
#  ('longitude', 'latitude', 'population', 'households', 'median_income'),
#  ('longitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population'),
#  ('longitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'households'),
#  ('longitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'median_income'),
#  ('longitude',
#   'housing_median_age',
#   'total_rooms',
#   'population',
#   'households'),
#  ('longitude',
#   'housing_median_age',
#   'total_rooms',
#   'population',
#   'median_income'),
#  ('longitude',
#   'housing_median_age',
#   'total_rooms',
#   'households',
#   'median_income'),
#  ('longitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'population',
#   'households'),
#  ('longitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'population',
#   'median_income'),
#  ('longitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'households',
#   'median_income'),
#  ('longitude',
#   'housing_median_age',
#   'population',
#   'households',
#   'median_income'),
#  ('longitude', 'total_rooms', 'total_bedrooms', 'population', 'households'),
#  ('longitude', 'total_rooms', 'total_bedrooms', 'population', 'median_income'),
#  ('longitude', 'total_rooms', 'total_bedrooms', 'households', 'median_income'),
#  ('longitude', 'total_rooms', 'population', 'households', 'median_income'),
#  ('longitude', 'total_bedrooms', 'population', 'households', 'median_income'),
#  ('latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population'),
#  ('latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'households'),
#  ('latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'median_income'),
#  ('latitude', 'housing_median_age', 'total_rooms', 'population', 'households'),
#  ('latitude',
#   'housing_median_age',
#   'total_rooms',
#   'population',
#   'median_income'),
#  ('latitude',
#   'housing_median_age',
#   'total_rooms',
#   'households',
#   'median_income'),
#  ('latitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'population',
#   'households'),
#  ('latitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'population',
#   'median_income'),
#  ('latitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'households',
#   'median_income'),
#  ('latitude',
#   'housing_median_age',
#   'population',
#   'households',
#   'median_income'),
#  ('latitude', 'total_rooms', 'total_bedrooms', 'population', 'households'),
#  ('latitude', 'total_rooms', 'total_bedrooms', 'population', 'median_income'),
#  ('latitude', 'total_rooms', 'total_bedrooms', 'households', 'median_income'),
#  ('latitude', 'total_rooms', 'population', 'households', 'median_income'),
#  ('latitude', 'total_bedrooms', 'population', 'households', 'median_income'),
#  ('housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'households'),
#  ('housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'median_income'),
#  ('housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'households',
#   'median_income'),
#  ('housing_median_age',
#   'total_rooms',
#   'population',
#   'households',
#   'median_income'),
#  ('housing_median_age',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income'),
#  ('total_rooms',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'households'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'population',
#   'households'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'population',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'households',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'population',
#   'households'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'population',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'households',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'population',
#   'households',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'households'),
#  ('longitude',
#   'latitude',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'total_rooms',
#   'total_bedrooms',
#   'households',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'total_rooms',
#   'population',
#   'households',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income'),
#  ('longitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'households'),
#  ('longitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'median_income'),
#  ('longitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'households',
#   'median_income'),
#  ('longitude',
#   'housing_median_age',
#   'total_rooms',
#   'population',
#   'households',
#   'median_income'),
#  ('longitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income'),
#  ('longitude',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income'),
#  ('latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'households'),
#  ('latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'median_income'),
#  ('latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'households',
#   'median_income'),
#  ('latitude',
#   'housing_median_age',
#   'total_rooms',
#   'population',
#   'households',
#   'median_income'),
#  ('latitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income'),
#  ('latitude',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income'),
#  ('housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'households'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'households',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'population',
#   'households',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income'),
#  ('longitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income'),
#  ('latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income'),
#  ('longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income')]
